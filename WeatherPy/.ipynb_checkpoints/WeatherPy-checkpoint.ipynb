# %% [markdown]
# # WeatherPy -- Original data
#
# ---
#
# ## Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from config2 import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tabou
# Processing Record 2 of Set 1 | nadi
# Processing Record 3 of Set 1 | touros
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | qaqortoq
# Processing Record 6 of Set 1 | grytviken
# Processing Record 7 of Set 1 | opuwo
# Processing Record 8 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | anadyr
# Processing Record 11 of Set 1 | nuku'alofa
# Processing Record 12 of Set 1 | alo
# Processing Record 13 of Set 1 | espargos
# City not found. Skipping...
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 16 of Set 1 | blackmans bay
# Processing Record 17 of Set 1 | saurimo
# Processing Record 18 of Set 1 | nar'yan-mar
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | mana
# Processing Record 21 of Set 1 | vodnyy
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | taoudenni
# Processing Record 24 of Set 1 | cole harbour
# Processing Record 25 of Set 1 | port-aux-francais
# Processing Record 26 of Set 1 | olonkinbyen
# Processing Record 27 of Set 1 | mount isa
# Processing Record 28 of Set 1 | panaba
# Processing Record 29 of Set 1 | nchelenge
# Processing Record 30 of Set 1 | saint-francois
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | waitangi
# Processing Record 33 of Set 1 | port mathurin
# Processing Record 34 of Set 1 | kirensk
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | santona
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | alofi
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | santiago del torno
# Processing Record 43 of Set 1 | invercargill
# Processing Record 44 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 45 of Set 1 | winejok
# City not found. Skipping...
# Processing Record 46 of Set 1 | popondetta
# Processing Record 47 of Set 1 | margate
# Processing Record 48 of Set 1 | vorgashor
# Processing Record 49 of Set 1 | ulsteinvik
# Processing Record 50 of Set 1 | beyneu
# Processing Record 0 of Set 2 | sinabang
# Processing Record 1 of Set 2 | pariaman
# Processing Record 2 of Set 2 | linhares
# Processing Record 3 of Set 2 | phalaborwa
# Processing Record 4 of Set 2 | xinyuan
# Processing Record 5 of Set 2 | trondheim
# Processing Record 6 of Set 2 | scarborough
# Processing Record 7 of Set 2 | brisas de zicatela
# Processing Record 8 of Set 2 | belmonte
# Processing Record 9 of Set 2 | melekeok village
# Processing Record 10 of Set 2 | celestun
# Processing Record 11 of Set 2 | caleta de carquin
# Processing Record 12 of Set 2 | margaret river
# Processing Record 13 of Set 2 | fort bragg
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | uturoa
# Processing Record 16 of Set 2 | timaru
# Processing Record 17 of Set 2 | praia da vitoria
# Processing Record 18 of Set 2 | bilibino
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | paragominas
# Processing Record 21 of Set 2 | lebu
# Processing Record 44 of Set 3 | balikpapan
# Processing Record 45 of Set 3 | puerto aysen
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | jammalamadugu
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | atafu village
# Processing Record 0 of Set 4 | daru
# Processing Record 1 of Set 4 | villa bruzual
# Processing Record 2 of Set 4 | al ghayzah
# Processing Record 3 of Set 4 | ha tinh
# Processing Record 4 of Set 4 | ghanzi
# Processing Record 5 of Set 4 | chernomorskoye
# Processing Record 6 of Set 4 | udachny
# Processing Record 7 of Set 4 | bel ombre
# Processing Record 8 of Set 4 | kargil
# Processing Record 9 of Set 4 | ceylanpinar
# Processing Record 10 of Set 4 | middlesboro
# Processing Record 11 of Set 4 | katsuura
# Processing Record 12 of Set 4 | lompoc
# Processing Record 13 of Set 4 | raja
# Processing Record 14 of Set 4 | winona
# Processing Record 15 of Set 4 | bilopillya
# Processing Record 16 of Set 4 | nayoro
# Processing Record 17 of Set 4 | wailua homesteads
# Processing Record 18 of Set 4 | kaa-khem
# Processing Record 19 of Set 4 | westport
# Processing Record 20 of Set 4 | aasiaat
# Processing Record 21 of Set 4 | arraial do cabo
# Processing Record 22 of Set 4 | ivins
# Processing Record 23 of Set 4 | casas grandes
# Processing Record 24 of Set 4 | enewetak
# Processing Record 25 of Set 4 | mont-tremblant
# Processing Record 26 of Set 4 | outokumpu
# Processing Record 27 of Set 4 | quelimane
# Processing Record 28 of Set 4 | pacific grove
# Processing Record 29 of Set 4 | divnomorskoye
# Processing Record 30 of Set 4 | port saint john's
# Processing Record 31 of Set 4 | henderson
# Processing Record 32 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 33 of Set 4 | altamira
# Processing Record 34 of Set 4 | cidreira
# Processing Record 35 of Set 4 | imperatriz
# Processing Record 36 of Set 4 | mairinque
# Processing Record 37 of Set 4 | college
# Processing Record 38 of Set 4 | kill devil hills
# Processing Record 39 of Set 4 | bubaque
# Processing Record 40 of Set 4 | sopela
# Processing Record 41 of Set 4 | hassi messaoud
# Processing Record 42 of Set 4 | carnarvon
# Processing Record 43 of Set 4 | khorixas
# Processing Record 44 of Set 4 | qarazhal
# Processing Record 45 of Set 4 | at taj
# Processing Record 46 of Set 4 | ketchikan
# Processing Record 47 of Set 4 | jardim
# Processing Record 48 of Set 4 | kirkwall
# Processing Record 49 of Set 4 | verkhniy tagil
# Processing Record 0 of Set 5 | sulak
# Processing Record 1 of Set 5 | golfito
# Processing Record 2 of Set 5 | constantia
# Processing Record 3 of Set 5 | amga
# Processing Record 4 of Set 5 | vadso
# Processing Record 5 of Set 5 | nogent-sur-seine
# Processing Record 6 of Set 5 | fannuj
# City not found. Skipping...
# Processing Record 7 of Set 5 | vilyuchinsk
# Processing Record 8 of Set 5 | qapqal
# City not found. Skipping...
# Processing Record 9 of Set 5 | povoa de santa iria
# Processing Record 10 of Set 5 | lubumbashi
# Processing Record 11 of Set 5 | pierre
# Processing Record 12 of Set 5 | bandar lampung
# Processing Record 13 of Set 5 | papatowai
# Processing Record 14 of Set 5 | qusmuryn
# Processing Record 15 of Set 5 | meadow lake
# Processing Record 16 of Set 5 | sao miguel do araguaia
# Processing Record 17 of Set 5 | payakumbuh
# Processing Record 18 of Set 5 | norilsk
# Processing Record 19 of Set 5 | linxi
# Processing Record 20 of Set 5 | saint-philippe
# Processing Record 21 of Set 5 | bikin
# Processing Record 22 of Set 5 | kasongo-lunda
# Processing Record 23 of Set 5 | tsiombe
# Processing Record 24 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 25 of Set 5 | dembi dolo
# Processing Record 26 of Set 5 | yakymivka
# Processing Record 27 of Set 5 | polyarnyy
# Processing Record 28 of Set 5 | alice springs
# Processing Record 29 of Set 5 | yuzhno-sukhokumsk
# Processing Record 30 of Set 5 | happy valley-goose bay
# Processing Record 31 of Set 5 | serdar
# Processing Record 32 of Set 5 | kanggye
# Processing Record 33 of Set 5 | mabai
# Processing Record 34 of Set 5 | okhotsk
# Processing Record 35 of Set 5 | saint-yrieix-la-perche
# Processing Record 36 of Set 5 | yoichi
# Processing Record 37 of Set 5 | colima
# Processing Record 38 of Set 5 | beruniy
# Processing Record 39 of Set 5 | utrik
# Processing Record 40 of Set 5 | port alfred
# Processing Record 41 of Set 5 | fatezh
# Processing Record 42 of Set 5 | savannakhet
# Processing Record 43 of Set 5 | taiyuan
# Processing Record 44 of Set 5 | kuala tungkal
# Processing Record 45 of Set 5 | sulphur springs
# Processing Record 46 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 5 | tucuma
# Processing Record 48 of Set 5 | el gouna
# Processing Record 49 of Set 5 | georgetown
# Processing Record 0 of Set 6 | haparanda
# Processing Record 1 of Set 6 | isafjordur
# Processing Record 2 of Set 6 | zilair
# Processing Record 3 of Set 6 | howard springs
# Processing Record 4 of Set 6 | bandon
# Processing Record 5 of Set 6 | talcahuano
# Processing Record 6 of Set 6 | biala podlaska
# Processing Record 7 of Set 6 | donduseni
# Processing Record 8 of Set 6 | afaahiti
# Processing Record 9 of Set 6 | sisimiut
# Processing Record 10 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 11 of Set 6 | flying fish cove
# Processing Record 12 of Set 6 | hawaiian paradise park
# Processing Record 13 of Set 6 | ain beni mathar
# City not found. Skipping...
# Processing Record 14 of Set 6 | lihue
# Processing Record 15 of Set 6 | minas de marcona
# Processing Record 16 of Set 6 | callao
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | biryusinsk
# Processing Record 19 of Set 6 | verkhotur'ye
# Processing Record 20 of Set 6 | alamos
# Processing Record 21 of Set 6 | sol'-iletsk
# Processing Record 22 of Set 6 | mae hong son
# Processing Record 23 of Set 6 | port macquarie
# Processing Record 24 of Set 6 | harstad
# Processing Record 25 of Set 6 | puerto deseado
# Processing Record 26 of Set 6 | plesetsk
# Processing Record 27 of Set 6 | yurty
# Processing Record 28 of Set 6 | bruay-sur-l'escaut
# Processing Record 29 of Set 6 | iskateley
# Processing Record 30 of Set 6 | vorkuta
# Processing Record 31 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 32 of Set 6 | kavaratti
# Processing Record 33 of Set 6 | elliot lake
# Processing Record 34 of Set 6 | vernon
# Processing Record 35 of Set 6 | kentau
# Processing Record 33 of Set 9 | walvis bay
# Processing Record 34 of Set 9 | antsohihy
# Processing Record 35 of Set 9 | box elder
# Processing Record 36 of Set 9 | port hedland
# Processing Record 37 of Set 9 | dudinka
# Processing Record 38 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 9 | bakanas
# Processing Record 40 of Set 9 | irymple
# Processing Record 41 of Set 9 | manado
# Processing Record 42 of Set 9 | ribeira brava
# Processing Record 43 of Set 9 | nguigmi
# Processing Record 44 of Set 9 | calvi
# Processing Record 45 of Set 9 | chake chake
# Processing Record 46 of Set 9 | aluksne
# Processing Record 47 of Set 9 | turpan
# Processing Record 48 of Set 9 | dhuwaran
# Processing Record 49 of Set 9 | lwowek slaski
# Processing Record 0 of Set 10 | kavieng
# Processing Record 1 of Set 10 | khawr fakkan
# Processing Record 2 of Set 10 | kalyazin
# Processing Record 3 of Set 10 | fernley
# Processing Record 4 of Set 10 | great falls
# Processing Record 5 of Set 10 | ciudad constitucion
# Processing Record 6 of Set 10 | kuta
# Processing Record 7 of Set 10 | haiku-pauwela
# Processing Record 8 of Set 10 | tulun
# Processing Record 9 of Set 10 | puerto leguizamo
# Processing Record 10 of Set 10 | labrador city
# Processing Record 11 of Set 10 | soio
# Processing Record 12 of Set 10 | berea
# Processing Record 13 of Set 10 | moires
# Processing Record 14 of Set 10 | laguna de perlas
# Processing Record 15 of Set 10 | upington
# Processing Record 16 of Set 10 | cabedelo
# Processing Record 17 of Set 10 | nema
# Processing Record 18 of Set 10 | paita
# Processing Record 19 of Set 10 | howrah
# Processing Record 20 of Set 10 | tralee
# Processing Record 21 of Set 10 | mahibadhoo
# Processing Record 22 of Set 10 | acapulco de juarez
# Processing Record 23 of Set 10 | bairnsdale
# Processing Record 24 of Set 10 | tikhvin
# Processing Record 25 of Set 10 | masaya sur
# Processing Record 26 of Set 10 | ulladulla
# Processing Record 27 of Set 10 | salair
# Processing Record 28 of Set 10 | wuyang
# Processing Record 29 of Set 10 | cabanglasan
# Processing Record 30 of Set 10 | gorontalo
# Processing Record 31 of Set 10 | mata-utu
# Processing Record 32 of Set 10 | idil
# Processing Record 33 of Set 10 | yatou
# Processing Record 34 of Set 10 | bridgewater
# Processing Record 35 of Set 10 | huarmey
# Processing Record 36 of Set 10 | healesville
# Processing Record 37 of Set 10 | tataouine
# Processing Record 38 of Set 10 | madingou
# Processing Record 39 of Set 10 | tongliao
# Processing Record 40 of Set 10 | dalandzadgad
# Processing Record 41 of Set 10 | tympaki
# Processing Record 42 of Set 10 | an nuhud
# Processing Record 43 of Set 10 | iquitos
# Processing Record 44 of Set 10 | krasnomayskiy
# Processing Record 45 of Set 10 | burley
# Processing Record 46 of Set 10 | tondano
# Processing Record 47 of Set 10 | tanrake village
# City not found. Skipping...
# Processing Record 48 of Set 10 | olyokminsk
# Processing Record 49 of Set 10 | seoni
# Processing Record 0 of Set 11 | bardai
# Processing Record 1 of Set 11 | brush
# Processing Record 2 of Set 11 | san pedro pochutla
# Processing Record 3 of Set 11 | pangobilian
# Processing Record 4 of Set 11 | nogliki
# Processing Record 5 of Set 11 | rimus
# Processing Record 6 of Set 11 | tual
# Processing Record 7 of Set 11 | lliria
# Processing Record 8 of Set 11 | namibe
# Processing Record 9 of Set 11 | asau
# Processing Record 10 of Set 11 | nazret
# Processing Record 11 of Set 11 | bhabhua
# Processing Record 12 of Set 11 | douglas
# Processing Record 13 of Set 11 | glace bay
# Processing Record 14 of Set 11 | fort st. john
# Processing Record 15 of Set 11 | colonel hill
# Processing Record 16 of Set 11 | quellon
# Processing Record 17 of Set 11 | santa cruz
# Processing Record 18 of Set 11 | ha
# City not found. Skipping...
# Processing Record 19 of Set 11 | fukuecho
# Processing Record 20 of Set 11 | itaituba
# Processing Record 21 of Set 11 | palmer
# Processing Record 22 of Set 11 | paphos
# Processing Record 23 of Set 11 | mahanoro
# Processing Record 24 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 25 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 26 of Set 11 | puerto carreno
# Processing Record 27 of Set 11 | sinjar
# Processing Record 28 of Set 11 | yaren
# Processing Record 29 of Set 11 | pisco
# Processing Record 30 of Set 11 | kayar
# Processing Record 31 of Set 11 | mont-dore
# Processing Record 32 of Set 11 | laojunmiao
# Processing Record 33 of Set 11 | letlhakane
# Processing Record 34 of Set 11 | northam
# Processing Record 35 of Set 11 | chernyshevskiy
# Processing Record 36 of Set 11 | louhans
# Processing Record 37 of Set 11 | masonboro
# Processing Record 38 of Set 11 | gadzhiyevo
# Processing Record 39 of Set 11 | aldinga beach
# Processing Record 40 of Set 11 | bereket
# Processing Record 41 of Set 11 | 'ohonua
# City not found. Skipping...
# Processing Record 42 of Set 11 | ryotsu-minato
# Processing Record 43 of Set 11 | nouadhibou
# Processing Record 44 of Set 11 | piacabucu
# Processing Record 45 of Set 11 | shache
# Processing Record 46 of Set 11 | kisangani
# Processing Record 47 of Set 11 | jinka
# Processing Record 48 of Set 11 | amanganj
# Processing Record 49 of Set 11 | weyburn
# Processing Record 0 of Set 12 | kangding
# Processing Record 1 of Set 12 | maricopa
# Processing Record 2 of Set 12 | sumbawanga
# Processing Record 3 of Set 12 | rampur
# Processing Record 4 of Set 12 | mugia
# Processing Record 5 of Set 12 | san antonio de pale
# Processing Record 6 of Set 12 | illizi
# Processing Record 7 of Set 12 | manokwari
# Processing Record 8 of Set 12 | sao felix do xingu
# Processing Record 9 of Set 12 | gisborne
# Processing Record 10 of Set 12 | doka
# Processing Record 11 of Set 12 | usogorsk
# Processing Record 12 of Set 12 | sao jose da coroa grande
# Processing Record 13 of Set 12 | ban phe
# City not found. Skipping...
# Processing Record 14 of Set 12 | egilsstadir
# Processing Record 15 of Set 12 | port blair
# Processing Record 16 of Set 12 | isla mujeres
# Processing Record 17 of Set 12 | clinton
# Processing Record 18 of Set 12 | undurkhaan
# Processing Record 19 of Set 12 | christchurch
# Processing Record 20 of Set 12 | muli
# Processing Record 21 of Set 12 | ijebu-ife
# Processing Record 22 of Set 12 | rikaze
# Processing Record 23 of Set 12 | crescent city
# Processing Record 24 of Set 12 | kiffa
# Processing Record 25 of Set 12 | rio grande
# Processing Record 26 of Set 12 | pangody
# Processing Record 27 of Set 12 | thandla
# Processing Record 28 of Set 12 | raduzhnyy
# Processing Record 29 of Set 12 | sarykemer
# Processing Record 30 of Set 12 | kloulklubed
# Processing Record 31 of Set 12 | zhalantun
# Processing Record 32 of Set 12 | suva
# Processing Record 33 of Set 12 | midvagur
# Processing Record 34 of Set 12 | hobyo
# Processing Record 35 of Set 12 | kurchatov
# Processing Record 36 of Set 12 | kayangel
# Processing Record 37 of Set 12 | nizhniy odes
# Processing Record 38 of Set 12 | codrington
# Processing Record 39 of Set 12 | idri
# Processing Record 40 of Set 12 | yagry
# City not found. Skipping...
# Processing Record 41 of Set 12 | shenkursk
# Processing Record 42 of Set 12 | ambon
# Processing Record 43 of Set 12 | mount gambier
# Processing Record 44 of Set 12 | caluula
# Processing Record 45 of Set 12 | pathein
# Processing Record 46 of Set 12 | severo-yeniseyskiy
# Processing Record 47 of Set 12 | malango
# Processing Record 48 of Set 12 | oranjemund
# Processing Record 49 of Set 12 | brookings
# Processing Record 0 of Set 13 | hami
# Processing Record 1 of Set 13 | shingu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      tabou   4.4230   -7.3528    298.59        88          76        0.70
# 1       nadi -17.8000  177.4167    303.15        58          20        5.66
# 2     touros  -5.1989  -35.4608    299.64        69          51        7.08
# 3  adamstown -25.0660 -130.1015    294.44        69           0        4.72
# 4   qaqortoq  60.7167  -46.0333    265.57        66          66        2.45
#
#   Country        Date
# 0      CI  1700718129
# 1      FJ  1700718129
# 2      BR  1700718129
# 3      PN  1700717928
# 4      GL  1700718129

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            tabou   4.4230   -7.3528    298.59        88          76
# 1             nadi -17.8000  177.4167    303.15        58          20
# 2           touros  -5.1989  -35.4608    299.64        69          51
# 3        adamstown -25.0660 -130.1015    294.44        69           0
# 4         qaqortoq  60.7167  -46.0333    265.57        66          66
#
#          Wind Speed Country        Date
# City_ID
# 0              0.70      CI  1700718129
# 1              5.66      FJ  1700718129
# 2              7.08      BR  1700718129
# 3              4.72      PN  1700717928
# 4              2.45      GL  1700718129

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Convert temperatures from Kelvin to Celsius and Fahrenheit
city_data_df['Max Temp Celsius'] = [temp - 273.15 for temp in city_data_df['Max Temp']]

# Create a scatter plot for latitude vs. temperature (in Celsius)
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp Celsius'], marker="o", color="blue", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Max Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.grid(True)

plt.tight_layout()  # Adjust layout to prevent clipping of labels


# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker="o", color="blue", edgecolors="black", alpha=0.75)

# Incorporate the other graph propertie
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker="o", color="blue", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)


# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker="o", color="blue", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression_plot(x, y, xlabel, ylabel, title):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)

    # Create a scatter plot
    plt.scatter(x, y)
    
    # Plot the regression line
    regress_values = x * slope + intercept
    plt.plot(x, regress_values, "r-", label=f"y = {round(slope, 2)}x + {round(intercept, 2)}")

    # Annotate the line equation and r-value
    line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    r_value_annotation = f"r-value = {round(r_value, 2)}"
    
    # Print the r-value
    print(f"The r-value is: {r_value}")
    
    # Customize the plot
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()


    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display the new DataFrame
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           tabou   4.4230   -7.3528    298.59        88          76
# 4        qaqortoq  60.7167  -46.0333    265.57        66          66
# 7          albany  42.6001  -73.9662    280.11        92         100
# 8          anadyr  64.7500  177.4833    273.43        86          75
# 10            alo   7.4178    6.7371    296.90        95          28
#
#          Wind Speed Country        Date  Max Temp Celsius
# City_ID
# 0              0.70      CI  1700718129             25.44
# 4              2.45      GL  1700718129             -7.58
# 7              0.89      US  1700718130              6.96
# 8              8.00      RU  1700718055              0.28
# 10             1.07      NG  1700718130             23.75

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 nadi -17.8000  177.4167    303.15        58          20
# 2               touros  -5.1989  -35.4608    299.64        69          51
# 3            adamstown -25.0660 -130.1015    294.44        69           0
# 5            grytviken -54.2811  -36.5092    274.41        93         100
# 6                opuwo -18.0607   13.8400    300.55        27          52
# ...                ...      ...       ...       ...       ...         ...
# 558         codrington -38.2667  141.9667    291.22        67          80
# 561              ambon  -3.6954  128.1814    306.23        62          20
# 562      mount gambier -37.8333  140.7667    291.52        65          91
# 566            malango  -2.9627  119.9001    304.12        47          79
# 567         oranjemund -28.5500   16.4333    292.37        65           1
#
#          Wind Speed Country        Date  Max Temp Celsius
# City_ID
# 1              5.66      FJ  1700718129             30.00
# 2              7.08      BR  1700718129             26.49
# 3              4.72      PN  1700717928             21.29
# 5              2.73      GS  1700718129              1.26
# 6              2.51     NaN  1700718129             27.40
# ...             ...     ...         ...               ...
# 558            7.84      AU  1700718180             18.07
# 561            4.12      ID  1700718180             33.08
# 562            6.43      AU  1700718180             18.37
# 566            2.56      ID  1700718181             30.97
# 567            4.94     NaN  1700718012             19.22
#
# [174 rows x 10 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

northern_hemisphere_df = city_data_df[city_data_df['Lat'] >= 0]

# Call the function for the northern hemisphere
linear_regression_plot(
    northern_hemisphere_df['Lat'],
    northern_hemisphere_df['Max Temp Celsius'],
    'Latitude',
    'Max Temp (°C)',
    'Linear Regression - Northern Hemisphere'
)
# Out:
# The r-value is: -0.8753171864502891

# %%
# Linear regression on Southern Hemisphere

southern_hemisphere_df = city_data_df[city_data_df['Lat'] < 0]

# Call the function for the southern hemisphere
linear_regression_plot(
    southern_hemisphere_df['Lat'],
    southern_hemisphere_df['Max Temp Celsius'],
    'Latitude',
    'Max Temp (°C)',
    'Linear Regression - Southern Hemisphere'
)
# Out:
# The r-value is: 0.6142637239739379

# %% [markdown]
# **Discussion about the linear relationship:**
#
# ### Northern Hemisphere Insights:
# In the Northern Hemisphere, a compelling trend emerges. As latitude increases, there is a noticeable decrease in Max Temperature. The linear regression equation y=−0.67x+33.81 reflects this negative correlation, with a slope of -0.67. The high absolute R-value of -0.87 further reinforces the strength of this negative correlation. Essentially, higher latitudes in the Northern Hemisphere are consistently associated with lower Max Temperatures.
#
# ## Southern Hemisphere Observations:
# Conversely, the Southern Hemisphere exhibits a different temperature relationship with latitude. Here, an increase in latitude corresponds to an increase in Max Temperature. The linear regression equation y=0.3x+29.19 illustrates this positive correlation, featuring a slope of 0.3. While the positive correlation is moderate, as indicated by the R-value of 0.61, it underscores that higher latitudes in the Southern Hemisphere tend to be associated with higher Max Temperatures.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

northern_hemisphere_df = city_data_df[city_data_df['Lat'] >= 0]

# Call the function for the northern hemisphere
linear_regression_plot(
    northern_hemisphere_df['Lat'],
    northern_hemisphere_df['Humidity'],
    'Latitude',
    'Humidity (%)',
    'Linear Regression - Humidity vs. Latitude'
)
# Out:
# The r-value is: 0.2626492879035876

# %%
# Southern Hemisphere

southern_hemisphere_df = city_data_df[city_data_df['Lat'] < 0]

# Call the function for the southern hemisphere
linear_regression_plot(
    southern_hemisphere_df['Lat'],
    southern_hemisphere_df['Humidity'],
    'Latitude',
    'Humidity (%)',
    'Linear Regression - Humidity vs. Latitude'
)
# Out:
# The r-value is: 0.11849720291164971

# %% [markdown]
# **Discussion about the linear relationship:**
#
# ### Northern Hemisphere Analysis:
#
# The linear regression analysis for the Northern Hemisphere explores the connection between latitude (x) and humidity (y). The equation y=0.3x+60.67 signifies a positive correlation, suggesting that as one moves towards higher latitudes, humidity levels tend to increase. However, the relatively low R-value of 0.26 indicates a weak correlation. This implies that latitude alone has limited explanatory power in predicting humidity variations in the Northern Hemisphere. Other geographical and atmospheric factors, such as proximity to bodies of water or local weather patterns, likely contribute to the observed variations in humidity.
#
# ### Southern Hemisphere Analysis:
#
# Turning our focus to the Southern Hemisphere, the linear regression equation y=0.16x+76.1 depicts a positive correlation between latitude and humidity. In the Southern Hemisphere, higher latitudes correspond to higher humidity levels, although the correlation is weak, as indicated by the R-value of 0.11. This suggests that latitude alone does not provide a strong predictive measure for humidity in the Southern Hemisphere. Additional factors such as prevailing wind patterns, proximity to oceans, and local climatic conditions may play pivotal roles in influencing humidity levels.
# Comparative Analysis:
#
# Comparing the two hemispheres, both exhibit positive correlations between latitude and humidity, indicating a general trend of increasing humidity with higher latitudes. However, similar to the temperature analysis, the correlation is notably stronger in the Northern Hemisphere (R-value = 0.26) compared to the Southern Hemisphere (R-value = 0.11). These results emphasize the multifaceted nature of humidity dynamics, where latitude serves as an indicator but is not the sole determinant. Local environmental factors play crucial roles in shaping humidity patterns in both hemispheres, contributing to the observed variations.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

northern_hemisphere_df = city_data_df[city_data_df['Lat'] >= 0]

# Call the function for the northern hemisphere
linear_regression_plot(
    northern_hemisphere_df['Lat'],
    northern_hemisphere_df['Cloudiness'],
    'Latitude',
    'Cloudiness (%)',
    'Linear Regression - Cloudiness vs. Latitude'
)
# Out:
# The r-value is: 0.24492197393826376

# %%
# Southern Hemisphere
southern_hemisphere_df = city_data_df[city_data_df['Lat'] < 0]

# Call the function for the southern hemisphere
linear_regression_plot(
    southern_hemisphere_df['Lat'],
    southern_hemisphere_df['Cloudiness'],
    'Latitude',
    'Cloudiness (%)',
    'Linear Regression - Cloudiness vs. Latitude'
)
# Out:
# The r-value is: 0.18273551169415186

# %% [markdown]
# **Discussion about the linear relationship:**
#
# ### Northern Hemisphere Analysis:
#
# Exploring the relationship between cloudiness and latitude in the Northern Hemisphere, the linear regression equation y=0.5x+40.97 suggests a positive correlation. This indicates that, on average, cloudiness tends to increase as one moves towards higher latitudes. The R-value of 0.24 suggests a very weak positive correlation, implying that latitude explains a portion of the variability in cloudiness, although to a limited extent. The very weak correlation suggests that factors beyond latitude, such as local weather patterns and geographical features, significantly influence cloudiness in the Northern Hemisphere.
#
# ### Southern Hemisphere Analysis:
#
# In the Southern Hemisphere, the linear regression equation y=0.46x+68.54 illustrates a positive correlation between cloudiness and latitude. In the Southern Hemisphere, there is a tendency for increased cloudiness as one moves towards higher latitudes. However, the lower R-value of 0.18 indicates a weaker correlation compared to the Northern Hemisphere. This weaker correlation suggests that latitude alone is not a robust predictor of cloudiness in the Southern Hemisphere, and additional regional factors likely contribute substantially to cloudiness variations.
# Comparative Analysis:
#
# Comparing the two hemispheres, both exhibit positive correlations between latitude and cloudiness, indicating a general trend of increased cloudiness with higher latitudes. Nevertheless, the correlation is notably more pronounced in the Northern Hemisphere (R-value = 0.24) compared to the Southern Hemisphere (R-value = 0.18). These results underscore the influence of local climatic and geographical factors in shaping cloudiness patterns. While latitude serves as a useful indicator, it is evident that other regional variables significantly contribute to cloudiness variations in both hemispheres.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

northern_hemisphere_df = city_data_df[city_data_df['Lat'] >= 0]

# Call the function for the northern hemisphere
linear_regression_plot(
    northern_hemisphere_df['Lat'],
    northern_hemisphere_df['Wind Speed'],
    'Latitude',
    'Wind Speed (m/s)',
    'Linear Regression - Wind Speed vs. Latitude'
)
# Out:
# The r-value is: 0.2677430347735216

# %%
# Southern Hemisphere

southern_hemisphere_df = city_data_df[city_data_df['Lat'] < 0]

# Call the function for the southern hemisphere
linear_regression_plot(
    southern_hemisphere_df['Lat'],
    southern_hemisphere_df['Wind Speed'],
    'Latitude',
    'Wind Speed (m/s)',
    'Linear Regression - Cloudiness vs. Latitude'
)
# Out:
# The r-value is: -0.2831101643975921

# %% [markdown]
# **Discussion about the linear relationship:**
#
# ### Northern Hemisphere Analysis:
#
# Examining the relationship between wind speed and latitude in the Northern Hemisphere, the linear regression equation y=0.04x+2.15 suggests a positive correlation. This implies that, on average, wind speed tends to increase slightly as one moves towards higher latitudes. The R-value of 0.26 indicates a very weak positive correlation, implying that latitude explains a limited proportion of the variability in wind speed. The very weak correlation suggests that other factors, such as local topography and weather patterns, likely contribute significantly to variations in wind speed in the Northern Hemisphere.
#
# ### Southern Hemisphere Analysis:
#
# In the Southern Hemisphere, the linear regression equation y=−0.06x+2.86 illustrates a negative correlation between wind speed and latitude. This indicates that there is a tendency for decreased wind speed as one moves towards higher latitudes. However, the lower R-value of -0.2 indicates a weak negative correlation. This weaker correlation implies that latitude alone is not a strong predictor of wind speed in the Southern Hemisphere, and additional regional factors play substantial roles in influencing wind speed variations.
#
# Comparing the two hemispheres, both exhibit correlations between latitude and wind speed, but the relationships are notably weak. In the Northern Hemisphere, the correlation is weakly positive (R-value = 0.26), suggesting a slight increase in wind speed with higher latitudes. In the Southern Hemisphere, the correlation is weakly negative (R-value = -0.2), indicating a slight decrease in wind speed with higher latitudes. These findings emphasize the complexity of factors influencing wind speed, with latitude serving as only a modest indicator. It is evident that local geographic and atmospheric conditions contribute significantly to wind speed variations in both hemispheres.
